# %% [markdown]
# <a href="https://colab.research.google.com/github/Laballee/Deep-learning-fundamentals/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas numpy matplotlib statsmodels scipy
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.11.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.2->statsmodels) (1.16.0)

# %%
import numpy as np
import pandas as pd
import math
import sklearn
import sklearn.preprocessing
import datetime
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from scipy.stats import boxcox
import scipy.stats as stats
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.statespace.tools import diff
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("MMM.csv")
data = data.dropna()
data.head()
# Out:
#          Date  Open      High       Low     Close  Adj Close  Volume
# 0  1962-01-03   0.0  4.187500  4.085938  4.187500   0.719247  422400
# 1  1962-01-04   0.0  4.257813  4.187500  4.187500   0.719247  212800
# 2  1962-01-05   0.0  4.171875  4.062500  4.078125   0.700461  315200
# 3  1962-01-08   0.0  4.085938  4.031250  4.054688   0.696436  334400
# 4  1962-01-09   0.0  4.085938  4.039063  4.054688   0.696436  315200

# %%
data.tail()
# Out:
#              Date       Open       High        Low      Close  Adj Close  \
# 15570  2023-11-09  92.580002  93.209999  91.650002  91.699997  91.699997
# 15571  2023-11-10  92.000000  93.059998  91.660004  92.809998  92.809998
# 15572  2023-11-13  92.699997  93.129997  91.919998  92.690002  92.690002
# 15573  2023-11-14  94.000000  95.489998  93.930000  94.970001  94.970001
# 15574  2023-11-15  95.440002  97.199997  95.440002  96.820000  96.820000
#
#         Volume
# 15570  2124200
# 15571  2395000
# 15572  2133200
# 15573  3321400
# 15574  3789500

# %%
print(data.isnull().sum())
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Convert the 'Date' column to a datetime format
data['Date'] = pd.to_datetime(data['Date'])

# Set the data as a time series with the date as the index
data.set_index('Date', inplace=True)

# Plot the chart for adjusted closing prices over time
plt.figure(figsize=(8, 5))
plt.plot(data['Adj Close'])
plt.title('Adjusted Close Price Over Time')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')
plt.show()

# %%
# Converting the 'Adj Close' values to a time series data
data['log_adj_close'] = np.log(data['Adj Close'])

# Calculate the difference (residual) of the log-transformed 'Close' prices
data['differenced'] = data['log_adj_close'].diff()
data = data.iloc[1:]

# Plot the chart for differenced log-transformed closing prices
plt.plot(data['differenced'])
plt.title('Time Series After Log Transformation and Differencing')
plt.show()

# Plot the Autocorrelation Function (ACF)
fig, ax = plt.subplots(figsize=(6, 6))
plot_acf(data['differenced'].dropna(), ax=ax, lags=40)
plt.title('Autocorrelation Function (ACF)')

# Plot the Partial Autocorrelation Function (PACF)
fig, ax = plt.subplots(figsize=(6, 6))
plot_pacf(data['differenced'].dropna(), ax=ax, lags=40)
plt.title('Partial Autocorrelation Function (PACF)')

plt.show()

# %%
plt.figure(figsize=(8, 5))
# Create a normal probability plot using the differenced data
stats.probplot(data['differenced'].dropna(), dist='norm', plot=plt)
plt.title('Normal Probability Plot')
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 15574 entries, 1962-01-04 to 2023-11-15
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Open           15574 non-null  float64
#  1   High           15574 non-null  float64
#  2   Low            15574 non-null  float64
#  3   Close          15574 non-null  float64
#  4   Adj Close      15574 non-null  float64
#  5   Volume         15574 non-null  int64
#  6   log_adj_close  15574 non-null  float64
#  7   differenced    15574 non-null  float64
# dtypes: float64(7), int64(1)
# memory usage: 1.1 MB

# %%
data.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  15574.000000  15574.000000  15574.000000  15574.000000  15574.000000
# mean      51.845376     52.887989     51.987966     52.449100     36.294632
# std       58.896203     58.816848     57.920290     58.379314     49.898911
# min        0.000000      2.765625      2.570313      2.640625      0.454929
# 25%        7.359375      7.421875      7.296875      7.359375      1.724235
# 50%       25.062500     25.187500     24.890625     25.031250     10.499398
# 75%       80.317499     81.147501     79.647501     80.449997     49.206382
# max      258.510010    259.769989    255.970001    258.630005    209.277298
#
#              Volume  log_adj_close   differenced
# count  1.557400e+04   15574.000000  15574.000000
# mean   1.974551e+06       2.314452      0.000315
# std    2.010767e+06       1.806886      0.014664
# min    1.760000e+04      -0.787614     -0.226709
# 25%    5.296000e+05       0.544783     -0.007055
# 50%    1.630500e+06       2.351318      0.000000
# 75%    2.763275e+06       3.896023      0.007807
# max    5.053240e+07       5.343660      0.136629

# %%
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# Select other variables as features
features = ['Open', 'High', 'Low', 'Adj Close', 'Volume']
data['log_volume'] = np.log(data['Volume'])  # Log transform the 'Volume' variable

# Convert the data to numpy arrays
X = np.array(data[features])
y = np.array(data['differenced'])

# Normalize the data
scaler_X = MinMaxScaler(feature_range=(-1, 1))
scaler_y = MinMaxScaler(feature_range=(-1, 1))
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1))

# Create features with past time points and target variable
def create_dataset(dataset_X, dataset_y, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset_X)-look_back-1):
        a = dataset_X[i:(i+look_back), :]
        dataX.append(a)
        dataY.append(dataset_y[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

look_back = 10
X, y = create_dataset(X_scaled, y_scaled, look_back)

# Split the data into training, validation, and test sets
train_size = int(len(X) * 0.8)
valid_size = int(len(X) * 0.1)
test_size = len(X) - train_size - valid_size

trainX, trainY = X[0:train_size, :], y[0:train_size]
validX, validY = X[train_size:train_size + valid_size, :], y[train_size:train_size + valid_size]
testX, testY = X[train_size + valid_size:len(X), :], y[train_size + valid_size:]

# Reshape the input data to meet the requirements of the RNN input shape
trainX = np.reshape(trainX, (trainX.shape[0], look_back, len(features)))
validX = np.reshape(validX, (validX.shape[0], look_back, len(features)))
testX = np.reshape(testX, (testX.shape[0], look_back, len(features)))

# %%
print("Shape of trainX:", trainX.shape)
print("Shape of validX:", validX.shape)
# Out:
# Shape of trainX: (12450, 10, 5)
# Shape of validX: (1556, 10, 5)

# %%
# Build the RNN model
model = Sequential()
model.add(SimpleRNN(50, input_shape=(look_back, len(features)), activation='tanh'))
model.add(Dropout(0.2))  # Add a Dropout layer
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
epochs = 40
history = model.fit(trainX, trainY, epochs=epochs, batch_size=32, verbose=2, validation_data=(validX, validY))

# Predictions
trainPredict = model.predict(trainX)
validPredict = model.predict(validX)
testPredict = model.predict(testX)
# Out:
# Epoch 1/40
# 390/390 - 2s - loss: 0.0250 - val_loss: 0.0321 - 2s/epoch - 6ms/step
# Epoch 2/40
# 390/390 - 1s - loss: 0.0085 - val_loss: 0.0254 - 1s/epoch - 3ms/step
# Epoch 3/40
# 390/390 - 1s - loss: 0.0079 - val_loss: 0.0149 - 1s/epoch - 3ms/step
# Epoch 4/40
# 390/390 - 1s - loss: 0.0077 - val_loss: 0.0149 - 1s/epoch - 3ms/step
# Epoch 5/40
# 390/390 - 1s - loss: 0.0075 - val_loss: 0.0114 - 1s/epoch - 3ms/step
# Epoch 6/40
# 390/390 - 2s - loss: 0.0074 - val_loss: 0.0067 - 2s/epoch - 4ms/step
# Epoch 7/40
# 390/390 - 2s - loss: 0.0073 - val_loss: 0.0050 - 2s/epoch - 4ms/step
# Epoch 8/40
# 390/390 - 2s - loss: 0.0072 - val_loss: 0.0042 - 2s/epoch - 4ms/step
# Epoch 9/40
# 390/390 - 1s - loss: 0.0071 - val_loss: 0.0038 - 1s/epoch - 3ms/step
# Epoch 10/40
# 390/390 - 1s - loss: 0.0070 - val_loss: 0.0040 - 1s/epoch - 3ms/step
# Epoch 11/40
# 390/390 - 1s - loss: 0.0069 - val_loss: 0.0037 - 1s/epoch - 3ms/step
# Epoch 12/40
# 390/390 - 2s - loss: 0.0069 - val_loss: 0.0037 - 2s/epoch - 5ms/step
# Epoch 13/40
# 390/390 - 2s - loss: 0.0068 - val_loss: 0.0038 - 2s/epoch - 5ms/step
# Epoch 14/40
# 390/390 - 2s - loss: 0.0068 - val_loss: 0.0037 - 2s/epoch - 5ms/step
# Epoch 15/40
# 390/390 - 3s - loss: 0.0067 - val_loss: 0.0037 - 3s/epoch - 8ms/step
# Epoch 16/40
# 390/390 - 3s - loss: 0.0067 - val_loss: 0.0037 - 3s/epoch - 6ms/step
# Epoch 17/40
# 390/390 - 2s - loss: 0.0067 - val_loss: 0.0040 - 2s/epoch - 6ms/step
# Epoch 18/40
# 390/390 - 2s - loss: 0.0067 - val_loss: 0.0038 - 2s/epoch - 5ms/step
# Epoch 19/40
# 390/390 - 2s - loss: 0.0067 - val_loss: 0.0037 - 2s/epoch - 5ms/step
# Epoch 20/40
# 390/390 - 1s - loss: 0.0067 - val_loss: 0.0037 - 1s/epoch - 3ms/step
# Epoch 21/40
# 390/390 - 1s - loss: 0.0066 - val_loss: 0.0037 - 1s/epoch - 3ms/step
# Epoch 22/40
# 390/390 - 2s - loss: 0.0066 - val_loss: 0.0039 - 2s/epoch - 4ms/step
# Epoch 23/40
# 390/390 - 2s - loss: 0.0066 - val_loss: 0.0038 - 2s/epoch - 4ms/step
# Epoch 24/40
# 390/390 - 1s - loss: 0.0066 - val_loss: 0.0037 - 1s/epoch - 3ms/step
# Epoch 25/40
# 390/390 - 1s - loss: 0.0066 - val_loss: 0.0038 - 1s/epoch - 3ms/step
# Epoch 26/40
# 390/390 - 1s - loss: 0.0066 - val_loss: 0.0037 - 1s/epoch - 3ms/step
# Epoch 27/40
# 390/390 - 1s - loss: 0.0066 - val_loss: 0.0037 - 1s/epoch - 3ms/step
# Epoch 28/40
# 390/390 - 1s - loss: 0.0066 - val_loss: 0.0038 - 1s/epoch - 3ms/step
# Epoch 29/40
# 390/390 - 1s - loss: 0.0066 - val_loss: 0.0039 - 1s/epoch - 3ms/step
# Epoch 30/40
# 390/390 - 1s - loss: 0.0066 - val_loss: 0.0037 - 1s/epoch - 3ms/step
# Epoch 31/40
# 390/390 - 1s - loss: 0.0066 - val_loss: 0.0038 - 1s/epoch - 3ms/step
# Epoch 32/40
# 390/390 - 1s - loss: 0.0066 - val_loss: 0.0037 - 1s/epoch - 3ms/step
# Epoch 33/40
# 390/390 - 2s - loss: 0.0066 - val_loss: 0.0037 - 2s/epoch - 4ms/step
# Epoch 34/40
# 390/390 - 2s - loss: 0.0066 - val_loss: 0.0038 - 2s/epoch - 4ms/step
# Epoch 35/40
# 390/390 - 1s - loss: 0.0066 - val_loss: 0.0038 - 1s/epoch - 3ms/step
# Epoch 36/40
# 390/390 - 1s - loss: 0.0066 - val_loss: 0.0037 - 1s/epoch - 3ms/step
# Epoch 37/40
# 390/390 - 1s - loss: 0.0066 - val_loss: 0.0038 - 1s/epoch - 3ms/step
# Epoch 38/40
# 390/390 - 1s - loss: 0.0066 - val_loss: 0.0038 - 1s/epoch - 3ms/step
# Epoch 39/40
# 390/390 - 1s - loss: 0.0066 - val_loss: 0.0038 - 1s/epoch - 3ms/step
# Epoch 40/40
# 390/390 - 1s - loss: 0.0066 - val_loss: 0.0038 - 1s/epoch - 3ms/step
# 390/390 [==============================] - 1s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step

# %%
# Inverse transform the scaled predicted results
trainPredict = scaler_y.inverse_transform(trainPredict)
trainY = scaler_y.inverse_transform([trainY])
validPredict = scaler_y.inverse_transform(validPredict)
validY = scaler_y.inverse_transform([validY])
testPredict = scaler_y.inverse_transform(testPredict)
testY = scaler_y.inverse_transform([testY])

# Calculate the RMSE for the training set, validation set, and test set
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
validScore = np.sqrt(mean_squared_error(validY[0], validPredict[:,0]))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))

print(f'Train RMSE: {trainScore:.4f}')
print(f'Validation RMSE: {validScore:.4f}')
print(f'Test RMSE: {testScore:.4f}')
# Out:
# Train RMSE: 0.0147
# Validation RMSE: 0.0112
# Test RMSE: 0.0170

# %%
# Plot the training and validation loss curves
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

# Add labels and legend
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.show()

# %%
# Normalize each feature
testX_scaled = np.zeros_like(testX)
for i in range(testX.shape[-1]):
    testX_scaled[:,:,i] = scaler_X.fit_transform(testX[:,:,i])

# Reshape to the format (samples, time steps, features)
testX_scaled_reshaped = np.reshape(testX_scaled, (testX_scaled.shape[0], testX_scaled.shape[1], testX_scaled.shape[2]))

# Make predictions
testPredict_scaled = model.predict(testX_scaled_reshaped)

# Inverse normalize the predicted results
testPredict_original_diff = scaler_y.inverse_transform(testPredict_scaled)

# Apply the inverse exponential transformation
testPredict_original_log = np.exp(testPredict_original_diff.cumsum())

# Apply inverse exponential transformation to the true labels
testY_original_log = np.exp(testY.cumsum())

# Plot the results
plt.figure(figsize=(6, 6))
plt.plot(testY_original_log, label='Actual Closing Price', color='blue')
plt.plot(testPredict_original_log, label='Predicted Closing Price', color='orange')
plt.title('Actual vs Predicted Closing Price on Test Data')
plt.xlabel('Time Steps')
plt.ylabel('Closing Price')
plt.legend()
plt.show()
# Out:
# 49/49 [==============================] - 0s 2ms/step

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense

# Build LSTM model
look_back = 10
model_lstm = Sequential()
model_lstm.add(LSTM(50, input_shape=(look_back, len(features)), activation='tanh'))
model_lstm.add(Dropout(0.2))
model_lstm.add(Dense(1))
model_lstm.compile(loss='mean_squared_error', optimizer='adam')

# Reshape target data if needed
trainY = trainY.reshape(-1, 1)
validY = validY.reshape(-1, 1)
testY = testY.reshape(-1, 1)

# Train LSTM model
epochs = 40
history_lstm = model_lstm.fit(trainX, trainY, epochs=epochs, batch_size=32, verbose=2, validation_data=(validX, validY))

# Predictions
trainPredict_lstm = model_lstm.predict(trainX)
validPredict_lstm = model_lstm.predict(validX)
testPredict_lstm = model_lstm.predict(testX)
# Out:
# Epoch 1/40
# 390/390 - 5s - loss: 0.0029 - val_loss: 2.2775e-04 - 5s/epoch - 14ms/step
# Epoch 2/40
# 390/390 - 2s - loss: 3.1154e-04 - val_loss: 2.0276e-04 - 2s/epoch - 5ms/step
# Epoch 3/40
# 390/390 - 2s - loss: 2.7210e-04 - val_loss: 1.5265e-04 - 2s/epoch - 6ms/step
# Epoch 4/40
# 390/390 - 3s - loss: 2.6737e-04 - val_loss: 1.2871e-04 - 3s/epoch - 7ms/step
# Epoch 5/40
# 390/390 - 2s - loss: 2.5836e-04 - val_loss: 1.3339e-04 - 2s/epoch - 5ms/step
# Epoch 6/40
# 390/390 - 2s - loss: 2.4506e-04 - val_loss: 1.6296e-04 - 2s/epoch - 5ms/step
# Epoch 7/40
# 390/390 - 2s - loss: 2.4784e-04 - val_loss: 1.3008e-04 - 2s/epoch - 5ms/step
# Epoch 8/40
# 390/390 - 2s - loss: 2.4043e-04 - val_loss: 1.2972e-04 - 2s/epoch - 5ms/step
# Epoch 9/40
# 390/390 - 2s - loss: 2.3884e-04 - val_loss: 1.7878e-04 - 2s/epoch - 5ms/step
# Epoch 10/40
# 390/390 - 3s - loss: 2.3608e-04 - val_loss: 1.4990e-04 - 3s/epoch - 8ms/step
# Epoch 11/40
# 390/390 - 2s - loss: 2.3902e-04 - val_loss: 1.3688e-04 - 2s/epoch - 6ms/step
# Epoch 12/40
# 390/390 - 2s - loss: 2.2872e-04 - val_loss: 1.8032e-04 - 2s/epoch - 5ms/step
# Epoch 13/40
# 390/390 - 2s - loss: 2.3132e-04 - val_loss: 1.3829e-04 - 2s/epoch - 5ms/step
# Epoch 14/40
# 390/390 - 2s - loss: 2.3360e-04 - val_loss: 1.3332e-04 - 2s/epoch - 5ms/step
# Epoch 15/40
# 390/390 - 3s - loss: 2.2772e-04 - val_loss: 1.9771e-04 - 3s/epoch - 9ms/step
# Epoch 16/40
# 390/390 - 5s - loss: 2.2772e-04 - val_loss: 1.3303e-04 - 5s/epoch - 13ms/step
# Epoch 17/40
# 390/390 - 4s - loss: 2.2673e-04 - val_loss: 1.9730e-04 - 4s/epoch - 9ms/step
# Epoch 18/40
# 390/390 - 4s - loss: 2.2629e-04 - val_loss: 3.1342e-04 - 4s/epoch - 9ms/step
# Epoch 19/40
# 390/390 - 2s - loss: 2.2508e-04 - val_loss: 1.2740e-04 - 2s/epoch - 5ms/step
# Epoch 20/40
# 390/390 - 3s - loss: 2.2421e-04 - val_loss: 1.3352e-04 - 3s/epoch - 8ms/step
# Epoch 21/40
# 390/390 - 3s - loss: 2.2247e-04 - val_loss: 1.5397e-04 - 3s/epoch - 7ms/step
# Epoch 22/40
# 390/390 - 3s - loss: 2.2267e-04 - val_loss: 1.5894e-04 - 3s/epoch - 7ms/step
# Epoch 23/40
# 390/390 - 2s - loss: 2.2224e-04 - val_loss: 1.4739e-04 - 2s/epoch - 5ms/step
# Epoch 24/40
# 390/390 - 2s - loss: 2.2405e-04 - val_loss: 1.5897e-04 - 2s/epoch - 5ms/step
# Epoch 25/40
# 390/390 - 2s - loss: 2.2202e-04 - val_loss: 2.7885e-04 - 2s/epoch - 5ms/step
# Epoch 26/40
# 390/390 - 3s - loss: 2.2264e-04 - val_loss: 1.3520e-04 - 3s/epoch - 8ms/step
# Epoch 27/40
# 390/390 - 2s - loss: 2.2044e-04 - val_loss: 1.4557e-04 - 2s/epoch - 6ms/step
# Epoch 28/40
# 390/390 - 2s - loss: 2.2287e-04 - val_loss: 1.5234e-04 - 2s/epoch - 5ms/step
# Epoch 29/40
# 390/390 - 2s - loss: 2.2107e-04 - val_loss: 1.2933e-04 - 2s/epoch - 5ms/step
# Epoch 30/40
# 390/390 - 2s - loss: 2.1994e-04 - val_loss: 1.4187e-04 - 2s/epoch - 5ms/step
# Epoch 31/40
# 390/390 - 2s - loss: 2.2112e-04 - val_loss: 1.6691e-04 - 2s/epoch - 5ms/step
# Epoch 32/40
# 390/390 - 5s - loss: 2.1998e-04 - val_loss: 1.4530e-04 - 5s/epoch - 14ms/step
# Epoch 33/40
# 390/390 - 3s - loss: 2.2017e-04 - val_loss: 1.3631e-04 - 3s/epoch - 8ms/step
# Epoch 34/40
# 390/390 - 3s - loss: 2.1964e-04 - val_loss: 1.4845e-04 - 3s/epoch - 7ms/step
# Epoch 35/40
# 390/390 - 4s - loss: 2.1989e-04 - val_loss: 1.4898e-04 - 4s/epoch - 10ms/step
# Epoch 36/40
# 390/390 - 3s - loss: 2.1910e-04 - val_loss: 1.2278e-04 - 3s/epoch - 8ms/step
# Epoch 37/40
# 390/390 - 3s - loss: 2.1911e-04 - val_loss: 1.5264e-04 - 3s/epoch - 7ms/step
# Epoch 38/40
# 390/390 - 2s - loss: 2.1893e-04 - val_loss: 1.2317e-04 - 2s/epoch - 5ms/step
# Epoch 39/40
# 390/390 - 2s - loss: 2.1891e-04 - val_loss: 1.5981e-04 - 2s/epoch - 5ms/step
# Epoch 40/40
# 390/390 - 2s - loss: 2.1847e-04 - val_loss: 1.3231e-04 - 2s/epoch - 5ms/step
# 390/390 [==============================] - 1s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step

# %%
# Inverse transform the scaled predicted results for LSTM
trainPredict_lstm = scaler_y.inverse_transform(trainPredict_lstm)
trainY_lstm = scaler_y.inverse_transform(trainY.reshape(-1, 1))  # Adjust the shape of trainY
validPredict_lstm = scaler_y.inverse_transform(validPredict_lstm)
validY_lstm = scaler_y.inverse_transform(validY.reshape(-1, 1))  # Adjust the shape of validY
testPredict_lstm = scaler_y.inverse_transform(testPredict_lstm)
testY_lstm = scaler_y.inverse_transform(testY.reshape(-1, 1))  # Adjust the shape of testY

# Calculate the RMSE for the training set, validation set, and test set for LSTM
trainScore_lstm = np.sqrt(mean_squared_error(trainY_lstm, trainPredict_lstm[:, 0]))
validScore_lstm = np.sqrt(mean_squared_error(validY_lstm, validPredict_lstm[:, 0]))
testScore_lstm = np.sqrt(mean_squared_error(testY_lstm, testPredict_lstm[:, 0]))

# Print the RMSE for each set for LSTM
print(f'Train RMSE (LSTM): {trainScore_lstm:.4f}')
print(f'Validation RMSE (LSTM): {validScore_lstm:.4f}')
print(f'Test RMSE (LSTM): {testScore_lstm:.4f}')
# Out:
# Train RMSE (LSTM): 0.0027
# Validation RMSE (LSTM): 0.0021
# Test RMSE (LSTM): 0.0032

# %%
# Plot the training and validation loss curves for LSTM
plt.plot(history_lstm.history['loss'], label='LSTM Training Loss')
plt.plot(history_lstm.history['val_loss'], label='LSTM Validation Loss')

# Add labels and legend
plt.title('LSTM Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.show()

# %%
# Normalize each feature
testX_scaled = np.zeros_like(testX)
for i in range(testX.shape[-1]):
    testX_scaled[:,:,i] = scaler_X.fit_transform(testX[:,:,i])

# Reshape to the format (samples, time steps, features)
testX_scaled_reshaped = np.reshape(testX_scaled, (testX_scaled.shape[0], testX_scaled.shape[1], testX_scaled.shape[2]))

# Make predictions
testPredict_scaled = model_lstm.predict(testX_scaled_reshaped)

# Inverse normalize the predicted results
testPredict_original_diff = scaler_y.inverse_transform(testPredict_scaled)

# Apply the inverse exponential transformation
testPredict_original_log = np.exp(testPredict_original_diff.cumsum())

# Apply inverse exponential transformation to the true labels
testY_original_log = np.exp(testY.cumsum())

# Plot the results
plt.figure(figsize=(6, 6))
plt.plot(testY_original_log, label='Actual Closing Price', color='blue')
plt.plot(testPredict_original_log, label='Predicted Closing Price', color='orange')
plt.title('Actual vs Predicted Closing Price on Test Data')
plt.xlabel('Time Steps')
plt.ylabel('Closing Price')
plt.legend()
plt.show()
# Out:
# 49/49 [==============================] - 0s 2ms/step

# %%
from keras.layers import GRU

# Build GRU model
model_gru = Sequential()
model_gru.add(GRU(50, input_shape=(look_back, len(features)), activation='tanh'))
model_gru.add(Dropout(0.2))
model_gru.add(Dense(1))
model_gru.compile(loss='mean_squared_error', optimizer='adam')

# Train GRU model
history_gru = model_gru.fit(trainX, trainY, epochs=epochs, batch_size=32, verbose=2, validation_data=(validX, validY))

# Predictions
trainPredict_gru = model_gru.predict(trainX)
validPredict_gru = model_gru.predict(validX)
testPredict_gru = model_gru.predict(testX)
# Out:
# Epoch 1/40
# 390/390 - 5s - loss: 0.0064 - val_loss: 7.4709e-04 - 5s/epoch - 12ms/step
# Epoch 2/40
# 390/390 - 2s - loss: 5.3139e-04 - val_loss: 1.7772e-04 - 2s/epoch - 5ms/step
# Epoch 3/40
# 390/390 - 3s - loss: 3.4554e-04 - val_loss: 1.8945e-04 - 3s/epoch - 8ms/step
# Epoch 4/40
# 390/390 - 3s - loss: 3.1174e-04 - val_loss: 3.3524e-04 - 3s/epoch - 7ms/step
# Epoch 5/40
# 390/390 - 2s - loss: 2.8099e-04 - val_loss: 2.3170e-04 - 2s/epoch - 5ms/step
# Epoch 6/40
# 390/390 - 2s - loss: 2.7499e-04 - val_loss: 2.3627e-04 - 2s/epoch - 5ms/step
# Epoch 7/40
# 390/390 - 3s - loss: 2.6562e-04 - val_loss: 1.7319e-04 - 3s/epoch - 7ms/step
# Epoch 8/40
# 390/390 - 3s - loss: 2.5309e-04 - val_loss: 1.5625e-04 - 3s/epoch - 9ms/step
# Epoch 9/40
# 390/390 - 3s - loss: 2.5949e-04 - val_loss: 1.3699e-04 - 3s/epoch - 7ms/step
# Epoch 10/40
# 390/390 - 2s - loss: 2.5177e-04 - val_loss: 2.3454e-04 - 2s/epoch - 6ms/step
# Epoch 11/40
# 390/390 - 3s - loss: 2.4735e-04 - val_loss: 1.5318e-04 - 3s/epoch - 8ms/step
# Epoch 12/40
# 390/390 - 2s - loss: 2.4526e-04 - val_loss: 1.9908e-04 - 2s/epoch - 5ms/step
# Epoch 13/40
# 390/390 - 2s - loss: 2.5015e-04 - val_loss: 2.7828e-04 - 2s/epoch - 5ms/step
# Epoch 14/40
# 390/390 - 3s - loss: 2.4108e-04 - val_loss: 1.6645e-04 - 3s/epoch - 8ms/step
# Epoch 15/40
# 390/390 - 3s - loss: 2.3884e-04 - val_loss: 1.3581e-04 - 3s/epoch - 7ms/step
# Epoch 16/40
# 390/390 - 2s - loss: 2.3810e-04 - val_loss: 1.8924e-04 - 2s/epoch - 5ms/step
# Epoch 17/40
# 390/390 - 2s - loss: 2.3564e-04 - val_loss: 2.2586e-04 - 2s/epoch - 5ms/step
# Epoch 18/40
# 390/390 - 2s - loss: 2.3256e-04 - val_loss: 1.3778e-04 - 2s/epoch - 5ms/step
# Epoch 19/40
# 390/390 - 2s - loss: 2.2851e-04 - val_loss: 3.6121e-04 - 2s/epoch - 5ms/step
# Epoch 20/40
# 390/390 - 3s - loss: 2.3123e-04 - val_loss: 2.4543e-04 - 3s/epoch - 8ms/step
# Epoch 21/40
# 390/390 - 3s - loss: 2.2838e-04 - val_loss: 3.1496e-04 - 3s/epoch - 8ms/step
# Epoch 22/40
# 390/390 - 3s - loss: 2.2557e-04 - val_loss: 1.3222e-04 - 3s/epoch - 7ms/step
# Epoch 23/40
# 390/390 - 4s - loss: 2.2328e-04 - val_loss: 1.3167e-04 - 4s/epoch - 9ms/step
# Epoch 24/40
# 390/390 - 3s - loss: 2.2126e-04 - val_loss: 1.4517e-04 - 3s/epoch - 8ms/step
# Epoch 25/40
# 390/390 - 5s - loss: 2.2132e-04 - val_loss: 1.3669e-04 - 5s/epoch - 12ms/step
# Epoch 26/40
# 390/390 - 2s - loss: 2.2046e-04 - val_loss: 1.3801e-04 - 2s/epoch - 5ms/step
# Epoch 27/40
# 390/390 - 2s - loss: 2.2022e-04 - val_loss: 1.3294e-04 - 2s/epoch - 5ms/step
# Epoch 28/40
# 390/390 - 3s - loss: 2.1958e-04 - val_loss: 1.3096e-04 - 3s/epoch - 8ms/step
# Epoch 29/40
# 390/390 - 2s - loss: 2.1899e-04 - val_loss: 1.2328e-04 - 2s/epoch - 5ms/step
# Epoch 30/40
# 390/390 - 3s - loss: 2.1933e-04 - val_loss: 1.2571e-04 - 3s/epoch - 8ms/step
# Epoch 31/40
# 390/390 - 3s - loss: 2.1947e-04 - val_loss: 1.2271e-04 - 3s/epoch - 6ms/step
# Epoch 32/40
# 390/390 - 2s - loss: 2.1937e-04 - val_loss: 1.2282e-04 - 2s/epoch - 5ms/step
# Epoch 33/40
# 390/390 - 3s - loss: 2.1907e-04 - val_loss: 1.2271e-04 - 3s/epoch - 7ms/step
# Epoch 34/40
# 390/390 - 2s - loss: 2.1952e-04 - val_loss: 1.3292e-04 - 2s/epoch - 5ms/step
# Epoch 35/40
# 390/390 - 2s - loss: 2.2015e-04 - val_loss: 1.6809e-04 - 2s/epoch - 6ms/step
# Epoch 36/40
# 390/390 - 6s - loss: 2.1908e-04 - val_loss: 1.2546e-04 - 6s/epoch - 15ms/step
# Epoch 37/40
# 390/390 - 4s - loss: 2.1895e-04 - val_loss: 1.2305e-04 - 4s/epoch - 10ms/step
# Epoch 38/40
# 390/390 - 2s - loss: 2.2026e-04 - val_loss: 1.4628e-04 - 2s/epoch - 5ms/step
# Epoch 39/40
# 390/390 - 2s - loss: 2.1927e-04 - val_loss: 1.2293e-04 - 2s/epoch - 6ms/step
# Epoch 40/40
# 390/390 - 3s - loss: 2.1912e-04 - val_loss: 1.2477e-04 - 3s/epoch - 8ms/step
# 390/390 [==============================] - 1s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step

# %%
# Inverse transform the scaled predicted results for GRU
trainPredict_gru = scaler_y.inverse_transform(trainPredict_gru)
trainY_gru = scaler_y.inverse_transform(trainY)
validPredict_gru = scaler_y.inverse_transform(validPredict_gru)
validY_gru = scaler_y.inverse_transform(validY)
testPredict_gru = scaler_y.inverse_transform(testPredict_gru)
testY_gru = scaler_y.inverse_transform(testY)

# Calculate the RMSE for the training set, validation set, and test set for GRU
trainScore_gru = np.sqrt(mean_squared_error(trainY_gru, trainPredict_gru[:, 0]))
validScore_gru = np.sqrt(mean_squared_error(validY_gru, validPredict_gru[:, 0]))
testScore_gru = np.sqrt(mean_squared_error(testY_gru, testPredict_gru[:, 0]))

# Print the RMSE for each set for GRU
print(f'Train RMSE (GRU): {trainScore_gru:.4f}')
print(f'Validation RMSE (GRU): {validScore_gru:.4f}')
print(f'Test RMSE (GRU): {testScore_gru:.4f}')
# Out:
# Train RMSE (GRU): 0.0027
# Validation RMSE (GRU): 0.0020
# Test RMSE (GRU): 0.0031

# %%
# Plot the training and validation loss curves for GRU
plt.plot(history_gru.history['loss'], label='GRU Training Loss')
plt.plot(history_gru.history['val_loss'], label='GRU Validation Loss')

# Add labels and legend
plt.title('GRU Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.show()

# %%
# Normalize each feature
testX_scaled = np.zeros_like(testX)
for i in range(testX.shape[-1]):
    testX_scaled[:,:,i] = scaler_X.fit_transform(testX[:,:,i])

# Reshape to the format (samples, time steps, features)
testX_scaled_reshaped = np.reshape(testX_scaled, (testX_scaled.shape[0], testX_scaled.shape[1], testX_scaled.shape[2]))

# Make predictions
testPredict_scaled = model_gru.predict(testX_scaled_reshaped)

# Inverse normalize the predicted results
testPredict_original_diff = scaler_y.inverse_transform(testPredict_scaled)

# Apply the inverse exponential transformation
testPredict_original_log = np.exp(testPredict_original_diff.cumsum())

# Apply inverse exponential transformation to the true labels
testY_original_log = np.exp(testY.cumsum())

# Plot the results
plt.figure(figsize=(6, 6))
plt.plot(testY_original_log, label='Actual Closing Price', color='blue')
plt.plot(testPredict_original_log, label='Predicted Closing Price', color='orange')
plt.title('Actual vs Predicted Closing Price on Test Data')
plt.xlabel('Time Steps')
plt.ylabel('Closing Price')
plt.legend()
plt.show()
# Out:
# 49/49 [==============================] - 0s 2ms/step
